# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

plt.style.use('fivethirtyeight')
pd.set_option('max_column', 500)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[2], line 7
#       4 import plotly.express as px
#       6 plt.style.use('fivethirtyeight')
# ----> 7 pd.set_option('max_column', 500)
#
# File D:\anaconda3\Lib\site-packages\pandas\_config\config.py:263, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     262 def __call__(self, *args, **kwds) -> T:
# --> 263     return self.__func__(*args, **kwds)
#
# File D:\anaconda3\Lib\site-packages\pandas\_config\config.py:156, in _set_option(*args, **kwargs)
#     153     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     155 for k, v in zip(args[::2], args[1::2]):
# --> 156     key = _get_single_key(k, silent)
#     158     o = _get_registered_option(key)
#     159     if o and o.validator:
#
# File D:\anaconda3\Lib\site-packages\pandas\_config\config.py:123, in _get_single_key(pat, silent)
#     121     raise OptionError(f"No such keys(s): {repr(pat)}")
#     122 if len(keys) > 1:
# --> 123     raise OptionError("Pattern matched multiple keys")
#     124 key = keys[0]
#     126 if not silent:
#
# OptionError: Pattern matched multiple keys

# %%
# !pip install fredapi
# Out:
# Requirement already satisfied: fredapi in d:\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from fredapi) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\anaconda3\lib\site-packages (from pandas->fredapi) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\lib\site-packages (from pandas->fredapi) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in d:\anaconda3\lib\site-packages (from pandas->fredapi) (1.24.3)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->fredapi) (1.16.0)

# %%
from fredapi import Fred

# %%
fred=Fred(api_key=fred_key)

# %%
fred

# %%
sp_search=fred.search('S&P', order_by='popularity')

# %%
sp_search.shape
# Out:
# (1000, 15)

# %%
sp_search
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2023-11-26   2023-11-26
# CSUSHPINSA              CSUSHPINSA     2023-11-26   2023-11-26
# SP500                        SP500     2023-11-26   2023-11-26
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2023-11-26   2023-11-26
# MEHOINUSA672N        MEHOINUSA672N     2023-11-26   2023-11-26
# ...                            ...            ...          ...
# DDDM02LTA156NWDB  DDDM02LTA156NWDB     2023-11-26   2023-11-26
# DDEM01ECA156NWDB  DDEM01ECA156NWDB     2023-11-26   2023-11-26
# DDEM01JOA156NWDB  DDEM01JOA156NWDB     2023-11-26   2023-11-26
# QCZPAM770A              QCZPAM770A     2023-11-26   2023-11-26
# QCOPAMXDCU              QCOPAMXDCU     2023-11-26   2023-11-26
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# CSUSHPINSA          S&P/Case-Shiller U.S. National Home Price Index
# SP500                                                       S&P 500
# BAMLH0A0HYM2EY         ICE BofA US High Yield Index Effective Yield
# MEHOINUSA672N     Real Median Household Income in the United States
# ...                                                             ...
# DDDM02LTA156NWDB  Stock Market Total Value Traded to GDP for Lit...
# DDEM01ECA156NWDB  Stock Market Turnover Ratio (Value Traded/Capi...
# DDEM01JOA156NWDB  Stock Market Turnover Ratio (Value Traded/Capi...
# QCZPAM770A        Total Credit to Private Non-Financial Sector, ...
# QCOPAMXDCU        Total Credit to Private Non-Financial Sector, ...
#
#                  observation_start observation_end                  frequency  \
# series id
# BAMLH0A0HYM2            1996-12-31      2023-11-23               Daily, Close
# CSUSHPINSA              1987-01-01      2023-08-01                    Monthly
# SP500                   2013-11-25      2023-11-24               Daily, Close
# BAMLH0A0HYM2EY          1996-12-31      2023-11-23               Daily, Close
# MEHOINUSA672N           1984-01-01      2022-01-01                     Annual
# ...                            ...             ...                        ...
# DDDM02LTA156NWDB        2003-01-01      2004-01-01                     Annual
# DDEM01ECA156NWDB        1995-01-01      2000-01-01                     Annual
# DDEM01JOA156NWDB        2007-01-01      2020-01-01                     Annual
# QCZPAM770A              1993-01-01      2023-01-01  Quarterly, End of Quarter
# QCOPAMXDCU              1996-10-01      2023-01-01  Quarterly, End of Quarter
#
#                  frequency_short                           units  \
# series id
# BAMLH0A0HYM2                   D                         Percent
# CSUSHPINSA                     M              Index Jan 2000=100
# SP500                          D                           Index
# BAMLH0A0HYM2EY                 D                         Percent
# MEHOINUSA672N                  A  2022 CPI-U-RS Adjusted Dollars
# ...                          ...                             ...
# DDDM02LTA156NWDB               A                         Percent
# DDEM01ECA156NWDB               A                         Percent
# DDEM01JOA156NWDB               A                         Percent
# QCZPAM770A                     Q               Percentage of GDP
# QCOPAMXDCU                     Q     Billions of Argentine Pesos
#
#                                units_short      seasonal_adjustment  \
# series id
# BAMLH0A0HYM2                             %  Not Seasonally Adjusted
# CSUSHPINSA              Index Jan 2000=100  Not Seasonally Adjusted
# SP500                                Index  Not Seasonally Adjusted
# BAMLH0A0HYM2EY                           %  Not Seasonally Adjusted
# MEHOINUSA672N     2022 CPI-U-RS Adjusted $  Not Seasonally Adjusted
# ...                                    ...                      ...
# DDDM02LTA156NWDB                         %  Not Seasonally Adjusted
# DDEM01ECA156NWDB                         %  Not Seasonally Adjusted
# DDEM01JOA156NWDB                         %  Not Seasonally Adjusted
# QCZPAM770A               Percentage of GDP  Not Seasonally Adjusted
# QCOPAMXDCU         Bil. of Argentine Pesos  Not Seasonally Adjusted
#
#                  seasonal_adjustment_short               last_updated  \
# series id
# BAMLH0A0HYM2                           NSA  2023-11-24 10:19:01-06:00
# CSUSHPINSA                             NSA  2023-10-31 08:12:01-05:00
# SP500                                  NSA  2023-11-24 19:11:01-06:00
# BAMLH0A0HYM2EY                         NSA  2023-11-24 10:19:05-06:00
# MEHOINUSA672N                          NSA  2023-09-12 13:48:02-05:00
# ...                                    ...                        ...
# DDDM02LTA156NWDB                       NSA  2022-08-04 09:49:39-05:00
# DDEM01ECA156NWDB                       NSA  2022-08-04 09:48:42-05:00
# DDEM01JOA156NWDB                       NSA  2022-08-04 09:48:41-05:00
# QCZPAM770A                             NSA  2023-09-18 13:04:08-05:00
# QCOPAMXDCU                             NSA  2023-09-18 13:02:56-05:00
#
#                  popularity                                              notes
# series id
# BAMLH0A0HYM2             93  The ICE BofA Option-Adjusted Spreads (OASs) ar...
# CSUSHPINSA               88  For more information regarding the index, plea...
# SP500                    83  The observations for the S&P 500 represent the...
# BAMLH0A0HYM2EY           82  This data represents the effective yield of th...
# MEHOINUSA672N            81  Household data are collected as of March.  As ...
# ...                     ...                                                ...
# DDDM02LTA156NWDB          3  Total value of all traded shares in a stock ma...
# DDEM01ECA156NWDB          3  Total value of shares traded during the period...
# DDEM01JOA156NWDB          3  Total value of shares traded during the period...
# QCZPAM770A                3  Credit is provided by domestic banks, all othe...
# QCOPAMXDCU                3  Credit is provided by domestic banks, all othe...
#
# [1000 rows x 15 columns]

# %% [markdown]
# <h1>PULLING RAW DATA</h1>

# %%
sp500=fred.get_series(series_id='SP500')

# %%
sp500.plot(figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# <h1>PULL AND JOIN</h1>

# %%
ur=fred.search('unemployement')
ur
# Out:
#                                           id realtime_start realtime_end  \
# series id
# UNRATE                                UNRATE     2023-11-26   2023-11-26
# UNRATENSA                          UNRATENSA     2023-11-26   2023-11-26
# CCSA                                    CCSA     2023-11-26   2023-11-26
# CCNSA                                  CCNSA     2023-11-26   2023-11-26
# NROU                                    NROU     2023-11-26   2023-11-26
# ...                                      ...            ...          ...
# LRUNTTTTNLA156N              LRUNTTTTNLA156N     2023-11-26   2023-11-26
# KNOX947URN                        KNOX947URN     2023-11-26   2023-11-26
# LAUMT472894000000003A  LAUMT472894000000003A     2023-11-26   2023-11-26
# PHIL942UR                          PHIL942UR     2023-11-26   2023-11-26
# LAUMT423798000000003A  LAUMT423798000000003A     2023-11-26   2023-11-26
#
#                                                                    title  \
# series id
# UNRATE                                                 Unemployment Rate
# UNRATENSA                                              Unemployment Rate
# CCSA                             Continued Claims (Insured Unemployment)
# CCNSA                            Continued Claims (Insured Unemployment)
# NROU                                    Noncyclical Rate of Unemployment
# ...                                                                  ...
# LRUNTTTTNLA156N        Unemployment Rate: Aged 15 and over: All Perso...
# KNOX947URN                      Unemployment Rate in Knoxville, TN (MSA)
# LAUMT472894000000003A           Unemployment Rate in Knoxville, TN (MSA)
# PHIL942UR              Unemployment Rate in Philadelphia-Camden-Wilmi...
# LAUMT423798000000003A  Unemployment Rate in Philadelphia-Camden-Wilmi...
#
#                       observation_start observation_end  \
# series id
# UNRATE                       1948-01-01      2023-10-01
# UNRATENSA                    1948-01-01      2023-10-01
# CCSA                         1967-01-07      2023-11-11
# CCNSA                        1967-01-07      2023-11-11
# NROU                         1949-01-01      2025-10-01
# ...                                 ...             ...
# LRUNTTTTNLA156N              2000-01-01      2022-01-01
# KNOX947URN                   1990-01-01      2023-09-01
# LAUMT472894000000003A        1990-01-01      2022-01-01
# PHIL942UR                    1990-01-01      2023-09-01
# LAUMT423798000000003A        1990-01-01      2022-01-01
#
#                                      frequency frequency_short    units  \
# series id
# UNRATE                                 Monthly               M  Percent
# UNRATENSA                              Monthly               M  Percent
# CCSA                   Weekly, Ending Saturday               W   Number
# CCNSA                  Weekly, Ending Saturday               W   Number
# NROU                                 Quarterly               Q  Percent
# ...                                        ...             ...      ...
# LRUNTTTTNLA156N                         Annual               A  Percent
# KNOX947URN                             Monthly               M  Percent
# LAUMT472894000000003A                   Annual               A  Percent
# PHIL942UR                              Monthly               M  Percent
# LAUMT423798000000003A                   Annual               A  Percent
#
#                       units_short           seasonal_adjustment  \
# series id
# UNRATE                          %           Seasonally Adjusted
# UNRATENSA                       %       Not Seasonally Adjusted
# CCSA                       Number           Seasonally Adjusted
# CCNSA                      Number       Not Seasonally Adjusted
# NROU                            %       Not Seasonally Adjusted
# ...                           ...                           ...
# LRUNTTTTNLA156N                 %       Not Seasonally Adjusted
# KNOX947URN                      %       Not Seasonally Adjusted
# LAUMT472894000000003A           %       Not Seasonally Adjusted
# PHIL942UR                       %  Smoothed Seasonally Adjusted
# LAUMT423798000000003A           %       Not Seasonally Adjusted
#
#                       seasonal_adjustment_short               last_updated  \
# series id
# UNRATE                                       SA  2023-11-03 07:50:02-05:00
# UNRATENSA                                   NSA  2023-11-03 07:50:14-05:00
# CCSA                                         SA  2023-11-22 07:33:16-06:00
# CCNSA                                       NSA  2023-11-22 07:33:48-06:00
# NROU                                        NSA  2023-08-01 11:01:03-05:00
# ...                                         ...                        ...
# LRUNTTTTNLA156N                             NSA  2023-04-20 16:01:30-05:00
# KNOX947URN                                  NSA  2023-11-01 10:25:43-05:00
# LAUMT472894000000003A                       NSA  2023-05-03 10:35:50-05:00
# PHIL942UR                                   SSA  2023-11-01 13:31:32-05:00
# LAUMT423798000000003A                       NSA  2023-05-03 10:36:11-05:00
#
#                       popularity  \
# series id
# UNRATE                        94
# UNRATENSA                     54
# CCSA                          75
# CCNSA                         36
# NROU                          66
# ...                          ...
# LRUNTTTTNLA156N                1
# KNOX947URN                     1
# LAUMT472894000000003A          1
# PHIL942UR                      1
# LAUMT423798000000003A          1
#
#                                                                    notes
# series id
# UNRATE                 The unemployment rate represents the number of...
# UNRATENSA              The unemployment rate represents the number of...
# CCSA                   Continued claims, also referred to as insured ...
# CCNSA                  Continued claims, also referred to as insured ...
# NROU                   Starting with the July, 2021 report: An Update...
# ...                                                                  ...
# LRUNTTTTNLA156N        OECD Descriptor ID: LRUNTTTT OECD unit ID: PC ...
# KNOX947URN                                                          None
# LAUMT472894000000003A                                               None
# PHIL942UR                                                           None
# LAUMT423798000000003A                                               None
#
# [1000 rows x 15 columns]

# %%
urate=fred.get_series('UNRATE')
